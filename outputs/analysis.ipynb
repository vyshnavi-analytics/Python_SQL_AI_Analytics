# %%
import pandas as pd
df = pd.read_excel("recruitment_data.csv")
df.head()
df = pd.read_excel("recruitment_data.csv")
df.shape
df.head()
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
import pandas as pd

df = pd.read_excel("recruitment_data.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

df.shape
df.head()
df.info()
df = df.dropna(how="all")
df.info()
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.head()
df.sort_values(by="conversion_%", ascending=False)
df["cost_per_hire"] = df["avg_cost"] / df["hires"]
df
import matplotlib.pyplot as plt

df.plot(x="recruiter", y="hires", kind="bar")
plt.show()
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

df["cost_per_hire"] = df["avg_cost"] / df["hires"]

df.sort_values(by="conversion_%", ascending=False)
df["cost_per_hire"] = df["avg_cost"] / df["hires"]
df["cost_per_hire"] = df["cost_per_hire"].replace([float("inf")], 0)

summary.to_csv("recruitment_kpi_summary.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Recruiter         5 non-null      object
#  1   Applications      5 non-null      float64
#  2   Hires             5 non-null      float64
#  3   Conversion %      5 non-null      float64
#  4   Avg Time to hire  5 non-null      float64
#  5   Avg Cost          5 non-null      float64
# dtypes: float64(5), object(1)
# memory usage: 516.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Recruiter         5 non-null      object
#  1   Applications      5 non-null      float64
#  2   Hires             5 non-null      float64
#  3   Conversion %      5 non-null      float64
#  4   Avg Time to hire  5 non-null      float64
# ...
